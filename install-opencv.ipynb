# %%
# %pip install --upgrade --force-reinstall "numpy<2" opencv-python
# Out:
# ...
#      ---------------------------------------- 15.8/15.8 MB 9.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 44.0/44.0 MB 9.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 41.2/41.2 MB 9.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 40.2/40.2 MB 7.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 40.2/40.2 MB 7.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 39.0/39.0 MB 8.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 39.5/39.5 MB 7.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.2
#     Uninstalling numpy-2.4.2:
#       Successfully uninstalled numpy-2.4.2
# Note: you may need to restart the kernel to use updated packages.
# ...
